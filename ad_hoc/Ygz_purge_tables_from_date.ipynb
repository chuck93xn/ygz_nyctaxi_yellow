# %%
date_from = '2026-05-01'

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "nyctaxi_ygz.`01_bronze`.yellow_trips_raw")

dt.delete(f"tpep_pickup_datetime >= '{date_from}'")

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "nyctaxi_ygz.`02_silver`.yellow_trips_cleansed")

dt.delete(f"pickup_datetime >= '{date_from}'")

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "nyctaxi_ygz.`02_silver`.yellow_trips_enriched")

dt.delete(f"pickup_datetime >= '{date_from}'")

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "nyctaxi_ygz.`03_gold`.daily_trip_summary")

dt.delete(f"pickup_date >= '{date_from}'")
